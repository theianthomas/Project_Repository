# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress


# Study data files
county_health_data = "../Datasets/2019_County_Health_Data.csv"

# Read data and the study results
county_health_data = pd.read_csv(county_health_data)

# Show results
county_health_data.head()
# Out:
#     FIPS     State     County  Population  % Diabetic  \
# 0  51000  Virginia        NaN     8470020        10.0
# 1  51001  Virginia   Accomack       32545        15.2
# 2  51003  Virginia  Albemarle      107702         7.0
# 3  51005  Virginia  Alleghany       15122        12.6
# 4  51007  Virginia     Amelia       13020        13.5
#
#    # Primary Care Physicians  % Uninsured  Food Environment Index  % Obese  \
# 0                     6423.0     9.939772                     8.9     28.8
# 1                       16.0    17.860554                     8.0     34.4
# 2                      164.0    10.600492                     8.8     21.6
# 3                        8.0     9.834789                     8.2     31.3
# 4                        2.0    12.867079                     8.3     33.2
#
#    % Food Insecure  % Limited Access  Household Income  Graduation Rate  \
# 0             10.6          4.282214             71518             86.9
# 1             14.1          2.092269             44038             89.7
# 2              8.9          3.655561             77591             94.7
# 3             11.4          4.727222             49655             91.1
# 4             10.7          5.756433             54979             94.2
#
#    % Unemployed  Preventable Hosp. Rate
# 0      3.751905                  4454.0
# 1      4.821921                  4745.0
# 2      3.305948                  2837.0
# 3      4.866998                  8763.0
# 4      4.002562                  4809.0

# %%
comparison = county_health_data.loc[[7,44], :]
comparison
# Out:
#      FIPS     State     County  Population  % Diabetic  \
# 7   51013  Virginia  Arlington      234965         4.7
# 44  51089  Virginia      Henry       51227        16.5
#
#     # Primary Care Physicians  % Uninsured  Food Environment Index  % Obese  \
# 7                       178.0     7.233227                     9.4     19.6
# 44                       33.0    13.048254                     7.6     35.3
#
#     % Food Insecure  % Limited Access  Household Income  Graduation Rate  \
# 7               7.5          0.083965            114705             90.8
# 44             13.9          7.325828             41206             87.2
#
#     % Unemployed  Preventable Hosp. Rate
# 7       2.488187                  3001.0
# 44      4.973160                  5107.0

# %%
sort_percent = county_health_data.sort_values(
    ["% Diabetic"], ascending=True)

sort_percent[["County", "% Diabetic", "Household Income"]].head(10)
# Out:
#                    County  % Diabetic  Household Income
# 7               Arlington         4.7            114705
# 29                Fairfax         6.9            117989
# 53                Loudoun         6.9            136191
# 2               Albemarle         7.0             77591
# 96        Alexandria City         7.1             99959
# 60             Montgomery         7.3             54297
# 111     Harrisonburg City         7.7             44688
# 124          Radford City         7.8             40941
# 99   Charlottesville City         8.2             54034
# 113        Lexington City         8.9             47749

# %%
sort_percent = county_health_data.sort_values(
    ["% Diabetic"], ascending=False)

sort_percent[["County", "% Diabetic", "Household Income"]].head(10)
# Out:
#               County  % Diabetic  Household Income
# 44             Henry        16.5             41206
# 25        Cumberland        16.3             44699
# 58       Mecklenburg        16.0             42275
# 19      Charles City        16.0             54504
# 41           Halifax        15.8             42552
# 84       Southampton        15.5             49512
# 1           Accomack        15.2             44038
# 51         Lancaster        14.8             50793
# 64    Northumberland        14.7             53381
# 121  Petersburg City        14.7             36038

# %%
fig, ax = plt.subplots()

ax.scatter(county_health_data['Household Income'], county_health_data['% Diabetic'])
ax.set_title('All Counties - Diabetic Percentage and Income')
ax.set_xlabel('Household Income')
ax.set_ylabel('Percent Diabetic')

#Convert to floats and store household income and % diabetic as x and y values
x_values = county_health_data['Household Income'].astype('float')
y_values = county_health_data['% Diabetic'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color='red')

# label plot
plt.xlabel("Household Income")
plt.ylabel("Percent Diabetic")

# Print r square value
print(f"R squared: {rvalue}")

#show plot
plt.show()
# Out:
# R squared: -0.5335975917876026

# %%
# Filter data by County for the rows, and County, % Diabetic, and Household income
county_health_data.iloc[[7, 29, 53, 19, 25, 44, ], [2,4,11]].head(10)
# Out:
#           County  % Diabetic  Household Income
# 7      Arlington         4.7            114705
# 29       Fairfax         6.9            117989
# 53       Loudoun         6.9            136191
# 19  Charles City        16.0             54504
# 25    Cumberland        16.3             44699
# 44         Henry        16.5             41206

# %%
household_income = [114705, 117989, 136191, 54504, 44699, 41206]
percent_diabetic = [4.7, 6.9, 6.9, 16.0, 16.3, 16.5]
plt.scatter(household_income, percent_diabetic, color='b')
plt.xlabel('Household Income')
plt.ylabel('Percent Diabetic')
plt.title('Relationship Between Percent Diabetic and Income')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Filter data by County for the rows, and County, % Diabetic, and Household income
county_health_data.iloc[[7, 29, 53, 19, 25,44], [2,4,11]].head(10)
# Out:
#           County  % Diabetic  Household Income
# 7      Arlington         4.7            114705
# 29       Fairfax         6.9            117989
# 53       Loudoun         6.9            136191
# 19  Charles City        16.0             54504
# 25    Cumberland        16.3             44699
# 44         Henry        16.5             41206

# %%
import gmaps

gmaps.configure(api_key='AIzaSyDctHilxVrim7wg4W6L-zanULHexmAOsvA')

marker_locations = [
    (38.8816, -77.0910),
    (38.8462, -77.3064),
    (39.0768, -77.6536),
    (38.0567, -78.6115),
    (38.8048, -77.0469),
    (37.2070, -80.4104),
    (38.4496, -78.8689),
    (37.1318, -80.5764),
    (38.0293, -78.4767),
    (37.2268, -75.9928),
    (37.9036, -76.4100),
    (37.2279, -77.4019),
    (37.7700, -76.4660),
    (37.7063, -75.8069),
    (36.6789, -77.1025),
    (36.7660, -78.9283),
    (37.3439, -77.0713),
    (36.6422, -78.3842),
    (37.4964, -78.2449),
    (36.6589, -79.9640)    
]

fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps

gmaps.configure(api_key='AIzaSyDctHilxVrim7wg4W6L-zanULHexmAOsvA')

marker_locations = [
    (38.8816, -77.0910),
    (38.8462, -77.3064),
    (39.0768, -77.6536),
    (38.0567, -78.6115),
    (38.8048, -77.0469),
    (37.2070, -80.4104),
    (38.4496, -78.8689),
    (37.1318, -80.5764),
    (38.0293, -78.4767)    
]

fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps

gmaps.configure(api_key='AIzaSyDctHilxVrim7wg4W6L-zanULHexmAOsvA')

marker_locations = [
    (37.2268, -75.9928),
    (37.9036, -76.4100),
    (37.2279, -77.4019),
    (37.7700, -76.4660),
    (37.7063, -75.8069),
    (36.6789, -77.1025),
    (36.7660, -78.9283),
    (37.3439, -77.0713),
    (36.6422, -78.3842),
    (37.4964, -78.2449),
    (36.6589, -79.9640)    
]

fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
